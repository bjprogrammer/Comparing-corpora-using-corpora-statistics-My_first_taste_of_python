# %%
import nltk
from urllib import request
url1 ="http://www.gutenberg.org/cache/epub/14721/pg14721.txt"
response1 = request.urlopen(url1)
file1 = response1.read().decode('utf8')
print(type(file1))
print(len(file1))
print(file1[:129])

url2 ="http://www.gutenberg.org/files/3188/3188-0.txt"
response2 = request.urlopen(url2)
file2 = response2.read().decode('utf8')
print(type(file2))
print(len(file2))
print(file2[:79])

url3 ="http://www.gutenberg.org/files/3197/3197-0.txt"
response3 = request.urlopen(url3)
file3 = response3.read().decode('utf8')
print(type(file3))
print(len(file3))
print(file3[:115])

import re
start = re.search(r"START OF THE PROJECT GUTENBERG EBOOK", file1).start()
stop = re.search(r"END OF THE PROJECT GUTENBERG EBOOK", file1).end()
AbrahamLincoln= file1[start:stop] 
AbrahamLincoln

start = re.search(r"START OF THIS PROJECT GUTENBERG EBOOK", file2).start()
stop = re.search(r"END OF THIS PROJECT GUTENBERG EBOOK", file2).end()
text2  = file2[start:stop] 

start = re.search(r"START OF THIS PROJECT GUTENBERG EBOOK", file3).start()
stop = re.search(r"END OF THIS PROJECT GUTENBERG EBOOK", file3).end()
text3  = file3[start:stop]

MarkTwain=text2 + text3
MarkTwain
# Out:
# <class 'str'>
# 536167
# ﻿The Project Gutenberg eBook, Speeches and Letters of Abraham Lincoln,
# 1832-1865, by Abraham Lincoln, Edited by Merwin Roe
#
#
#
# <class 'str'>
# 536917
# ﻿Project Gutenberg’s Mark Twain’s Speeches, by Mark Twain (Samuel
# Clemens)
#
#
# <class 'str'>
# 213279
# ﻿The Project Gutenberg EBook of The Letters Of Mark Twain, Volume 5,
# 1901-1906, by Mark Twain (Samuel Clemens)
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
altokens=CountVectorizer().build_tokenizer()(AbrahamLincoln)
alwords = [w.lower( ) for w in altokens] 
print(len(altokens))
alwords
# Out:
# 87663
# ['start',
#  'of',
#  'the',
#  'project',
#  'gutenberg',
#  'ebook',
#  'speeches',
#  'and',
#  'letters',
#  'of',
#  'abraham',
#  'lincoln',
#  '1832',
#  '1865',
#  'text',
#  'prepared',
#  'by',
#  'melanie',
#  'lybarger',
#  'suzanne',
#  'lybarger',
#  'and',
#  'the',
#  'project',
#  'gutenberg',
#  'online',
#  'distributed',
#  'proofreading',
#  'team',
#  'speeches',
#  'letters',
#  'of',
#  'abraham',
#  'lincoln',
#  '1832',
#  '1865',
#  'edited',
#  'by',
#  'merwin',
#  'roe',
#  'london',
#  'published',
#  'by',
#  'dent',
#  'sons',
#  'ltd',
#  'and',
#  'in',
#  'new',
#  'york',
#  'by',
#  'dutton',
#  'co',
#  'first',
#  'issue',
#  'of',
#  'this',
#  'edition',
#  '1907',
#  'reprinted',
#  '1909',
#  '1910',
#  '1912',
#  'mr',
#  'bryce',
#  'introduction',
#  'to',
#  'lincoln',
#  'speeches',
#  'is',
#  'printed',
#  'from',
#  'plates',
#  'made',
#  'and',
#  'type',
#  'set',
#  'by',
#  'the',
#  'university',
#  'press',
# ...

# %%
# function that takes a word and returns true if it consists only
#   of non-alphabetic characters  (assumes import re)
def alpha_filter(w):
  # pattern to match word of non-alphabetical characters
  pattern = re.compile('^[^a-z]+$')
  if (pattern.match(w)):
    return True
  else:
    return False

stopwords = nltk.corpus.stopwords.words('english')
print('number stopwords:', len(stopwords))
print(stopwords)

punctaltokens = nltk.wordpunct_tokenize("can't") 
punctalwords = [w.lower( ) for w in punctaltokens] 
print((punctalwords))

punctalwords = [w for w in punctalwords if not alpha_filter(w)]
print(len(punctalwords))

stoppedpunctalwords = [w for w in punctalwords if not w in stopwords]
print(len(stoppedpunctalwords))
stoppedpunctalwords
# Out:
# number stopwords: 153
# ...

# %%
waltokens = nltk.word_tokenize("wouldn't") 
print(len(waltokens))
walwords = [w.lower( ) for w in waltokens] 
print(len(walwords))

walwords = [w for w in walwords if not alpha_filter(w)]
print(len(walwords))

stoppedwalwords = [w for w in walwords if not w in stopwords]
print(len(stoppedwalwords))
stoppedwalwords
# Out:
# 2
# 2
# 2
# 2
# ['would', "n't"]

# %%
porter = nltk.PorterStemmer()
lancaster = nltk.LancasterStemmer()
wnl=nltk.WordNetLemmatizer()
from nltk.stem import SnowballStemmer
snowball_stemmer = SnowballStemmer('english')

crimePstem = [porter.stem(t) for t in stoppedwalwords]
crimeLstem = [lancaster.stem(t) for t in stoppedwalwords]
crimeSnstem = [snowball_stemmer.stem(t) for t in stoppedwalwords]

crimeLemma = [wnl.lemmatize(t) for t in stoppedwalwords]
alporterlemma = [porter.stem(t) for t in crimeLemma]
alporterlemma
# Out:
# ['start',
#  'project',
#  'gutenberg',
#  'ebook',
#  'speech',
#  'letter',
#  'abraham',
#  'lincoln',
#  'e-text',
#  'prepar',
#  'melani',
#  'lybarg',
#  'suzann',
#  'lybarg',
#  'project',
#  'gutenberg',
#  'onlin',
#  'distribut',
#  'proofread',
#  'team',
#  'speech',
#  'letter',
#  'abraham',
#  'lincoln',
#  'edit',
#  'merwin',
#  'roe',
#  'london',
#  'publish',
#  'j.',
#  'm.',
#  'dent',
#  'son',
#  'ltd',
#  'new',
#  'york',
#  'e.p',
#  'dutton',
#  'co',
#  'first',
#  'issu',
#  'edit',
#  'reprint',
#  'mr.',
#  'bryce',
#  "'s",
#  'introduct',
#  "'lincoln",
#  "'s",
#  'speech',
#  'print',
#  'plate',
#  'made',
#  'type',
#  'set',
#  'univers',
#  'press',
#  'cambridg',
#  'mass.',
#  'u.s.a.',
#  'taken',
#  'permiss',
#  "'the",
#  'complet',
#  'work',
#  'abraham',
#  'lincoln',
#  'centuri',
#  'compani',
#  'illustr',
#  'sent',
#  'great',
#  'voic',
#  'forth',
#  'breast',
#  'word',
#  'fell',
#  'like',
#  'winter',
#  'snow',
# ...

# %%
from nltk import FreqDist
emmadist = FreqDist(alporterlemma)
emmaitems = emmadist.most_common(50)
for item in emmaitems:
  print (item[0], '\t\t',item[1]/len(AbrahamLincoln))
# Out:
# state 		 0.0008208336882535601
# one 		 0.0006524079078807777
# slaveri 		 0.0006040096951299783
# upon 		 0.0005885222670497224
# would 		 0.0005672270534393706
# say 		 0.0005323803402587949
# peopl 		 0.0004955976985681873
# right 		 0.00047430248495783546
# constitut 		 0.00045300727134748366
# u 		 0.00044332762879732376
# men 		 0.00042396834369700395
# shall 		 0.00042009648667693997
# judg 		 0.00040848091561674813
# slave 		 0.00039105755902646026
# man 		 0.00038524977349636434
# may 		 0.00036976234541610846
# govern 		 0.0003465312032957247
# dougla 		 0.00034072341776562876
# union 		 0.00032136413266530895
# law 		 0.000315556347135213
# make 		 0.000313620418625181
# 's 		 0.00030781263309508506
# nation 		 0.00030200484756498914
# time 		 0.00030200484756498914
# question 		 0.00027683777693457336
# great 		 0.00027490184842454137
# think 		 0.0002632862773643495
# free 		 0.0002632862773643495
# declar 		 0.0002613503488543175
# made 		 0.0002536066348141896
# ...

# %%
morestopword=['upon','would','say','u','shall','\'s','could','must']
stopwords=stopwords+morestopword
stopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  'her',
#  'hers',
#  'herself',
#  'it',
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
# ...

# %%
alporterlemma = [w for w in alporterlemma if not w in stopwords]
emmadist = FreqDist(alporterlemma)
emmaitems = emmadist.most_common(50)
for item in emmaitems:
  print (item[0], '\t\t',item[1]/len(AbrahamLincoln))
# Out:
# state 		 0.0008208336882535601
# one 		 0.0006524079078807777
# slaveri 		 0.0006040096951299783
# peopl 		 0.0004955976985681873
# right 		 0.00047430248495783546
# constitut 		 0.00045300727134748366
# men 		 0.00042396834369700395
# judg 		 0.00040848091561674813
# slave 		 0.00039105755902646026
# man 		 0.00038524977349636434
# may 		 0.00036976234541610846
# govern 		 0.0003465312032957247
# dougla 		 0.00034072341776562876
# union 		 0.00032136413266530895
# law 		 0.000315556347135213
# make 		 0.000313620418625181
# nation 		 0.00030200484756498914
# time 		 0.00030200484756498914
# question 		 0.00027683777693457336
# great 		 0.00027490184842454137
# think 		 0.0002632862773643495
# free 		 0.0002632862773643495
# declar 		 0.0002613503488543175
# made 		 0.0002536066348141896
# let 		 0.00023811920673393373
# speech 		 0.00023037549269380581
# thing 		 0.00023037549269380581
# way 		 0.00023037549269380581
# said 		 0.00022650363567374183
# know 		 0.00022456770716370987
# ...

# %%
from nltk.collocations import *
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = BigramCollocationFinder.from_words(alporterlemma)
scored = finder.score_ngrams(bigram_measures.raw_freq)
for bscore in scored[:50]:
    print (bscore)
# Out:
# (('judg', 'dougla'), 0.0035883634499551454)
# (('unit', 'state'), 0.002229911572472126)
# (('dred', 'scott'), 0.0011790337049852621)
# (('slave', 'state'), 0.0009483531974881456)
# (('declar', 'independ'), 0.0008714596949891067)
# (('scott', 'decis'), 0.0008201973599897476)
# (('popular', 'sovereignti'), 0.000794566192490068)
# (('exclud', 'slaveri'), 0.0007176726899910291)
# (('suprem', 'court'), 0.0007176726899910291)
# (('missouri', 'compromis'), 0.0005895168524926311)
# (('men', 'creat'), 0.0005638856849929514)
# (('nebraska', 'bill'), 0.0005638856849929514)
# (('creat', 'equal'), 0.0005382545174932718)
# (('year', 'ago'), 0.0005382545174932718)
# (('constitut', 'unit'), 0.0005126233499935922)
# (('abraham', 'lincoln'), 0.000461361014994233)
# (('one', 'anoth'), 0.000461361014994233)
# (('free', 'state'), 0.00043572984749455336)
# (('institut', 'slaveri'), 0.00043572984749455336)
# (('slaveri', 'territori'), 0.00043572984749455336)
# (('public', 'mind'), 0.0004100986799948738)
# ...

# %%
Trigram_measures = nltk.collocations.TrigramAssocMeasures()
finder = TrigramCollocationFinder.from_words(alporterlemma)
scored = finder.score_ngrams(Trigram_measures.raw_freq)
for bscore in scored[:50]:
    print (bscore)
# Out:
# (('dred', 'scott', 'decis'), 0.0008201973599897476)
# (('constitut', 'unit', 'state'), 0.0005126233499935922)
# (('men', 'creat', 'equal'), 0.0005126233499935922)
# (('cours', 'ultim', 'extinct'), 0.0003332051774958349)
# (('frame', 'govern', 'live'), 0.0002563116749967961)
# (('end', 'slaveri', 'agit'), 0.0002306805074971165)
# (('father', 'frame', 'govern'), 0.0002306805074971165)
# (('care', 'whether', 'slaveri'), 0.0002050493399974369)
# (('public', 'mind', 'rest'), 0.0002050493399974369)
# (('whether', 'slaveri', 'vote'), 0.0002050493399974369)
# (('belief', 'cours', 'ultim'), 0.00017941817249775727)
# (('half', 'slave', 'half'), 0.00017941817249775727)
# (('mind', 'rest', 'belief'), 0.00017941817249775727)
# (('presid', 'unit', 'state'), 0.00017941817249775727)
# (('repeal', 'missouri', 'compromis'), 0.00017941817249775727)
# (('rest', 'belief', 'cours'), 0.00017941817249775727)
# (('slave', 'half', 'free'), 0.00017941817249775727)
# ...

# %%
finder3 = BigramCollocationFinder.from_words(alporterlemma)
finder3.apply_freq_filter(5)
scored = finder3.score_ngrams(bigram_measures.pmi)
for bscore in scored[:50]:
    print(bscore)
# Out:
# (('harper', 'ferri'), 12.666778778830352)
# (('h.', 'herndon'), 11.666778778830356)
# (('henri', 'clay'), 11.529275255080421)
# (('polic', 'regul'), 11.34485068394299)
# (('african', 'slave-trad'), 11.288267155576623)
# (('william', 'h.'), 11.251741279551512)
# (('annex', 'texa'), 11.181351951660112)
# (('pursuit', 'happi'), 10.749240939022329)
# (('ill.', 'oct.'), 10.666778778830352)
# (('push', 'forward'), 10.573669374438872)
# (('annual', 'messag'), 10.377272161635371)
# (('dear', 'sir'), 10.377272161635368)
# (('twelv', 'thousand'), 10.03451056333084)
# (('ultim', 'extinct'), 9.984954738856608)
# (('squatter', 'sovereignti'), 9.792309660914214)
# (('john', 'brown'), 9.743946639352815)
# (('dred', 'scott'), 9.728179323494496)
# (('wo', "n't"), 9.697152427873874)
# (('actual', 'presenc'), 9.676832443494279)
# (('herndon', 'washington'), 9.496853777388043)
# (('springfield', 'ill.'), 9.229373466523054)
# (('nebraska', 'bill'), 9.155625126541741)
# ...

# %%
finder3 = TrigramCollocationFinder.from_words(alporterlemma)
finder3.apply_freq_filter(5)
scored = finder3.score_ngrams(Trigram_measures.pmi)
for bscore in scored[:50]:
    print(bscore)
# Out:
# (('h.', 'herndon', 'washington'), 21.163632556218396)
# (('liberti', 'pursuit', 'happi'), 20.000982218573835)
# (('cours', 'ultim', 'extinct'), 19.293279546774485)
# (('life', 'liberti', 'pursuit'), 18.25555504565943)
# (('rest', 'belief', 'cours'), 18.0689287912243)
# (('belief', 'cours', 'ultim'), 17.90543005894142)
# (('mind', 'rest', 'belief'), 17.830141931637183)
# (('dred', 'scott', 'decis'), 17.623468632824252)
# (('repeal', 'missouri', 'compromis'), 17.582571493179568)
# (('proper', 'practic', 'relat'), 17.25614838107429)
# (('public', 'mind', 'rest'), 16.88952047871611)
# (('hous', 'divid', 'stand'), 16.724009418661282)
# (('suprem', 'court', 'decid'), 16.447207740493024)
# (('frame', 'govern', 'live'), 16.36431495322621)
# (('father', 'frame', 'govern'), 16.04238685833885)
# (('men', 'creat', 'equal'), 15.955886089341114)
# (('half', 'slave', 'half'), 15.74423337763508)
# (('idea', 'anyth', 'wrong'), 15.316377967683888)
# (('north', 'well', 'south'), 15.208438310436417)
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
wmttokens=CountVectorizer().build_tokenizer()(MarkTwain) 
print(len(wmttokens))
wmtwords = [w.lower( ) for w in wmttokens] 
print(len(wmtwords))

wmtwords = [w for w in wmtwords if not alpha_filter(w)]
print(len(wmtwords))

stoppedwmtwords = [w for w in wmtwords if not w in stopwords]
print(len(stoppedwmtwords))
stoppedwmtwords
# Out:
# 118853
# 118853
# 118308
# 55776
# ['start',
#  'project',
#  'gutenberg',
#  'ebook',
#  'mark',
#  'twain',
#  'speeches',
#  'produced',
#  'david',
#  'widger',
#  'mark',
#  'twain',
#  'speeches',
#  'mark',
#  'twain',
#  'contents',
#  'introduction',
#  'preface',
#  'story',
#  'speech',
#  'plymouth',
#  'rock',
#  'pilgrims',
#  'compliments',
#  'degrees',
#  'books',
#  'authors',
#  'hats',
#  'dedication',
#  'speech',
#  'die',
#  'schrecken',
#  'der',
#  'deutschen',
#  'sprache',
#  'german',
#  'hungarians',
#  'new',
#  'german',
#  'word',
#  'unconscious',
#  'plagiarism',
#  'weather',
#  'babies',
#  'children',
#  'great',
#  'discoveries',
#  'educating',
#  'theatre',
#  'goers',
#  'educational',
#  'theatre',
#  'poets',
#  'policemen',
#  'pudd',
#  'nhead',
#  'wilson',
#  'dramatized',
#  'daly',
#  'theatre',
#  'dress',
#  'civilized',
#  'woman',
#  'dress',
#  'reform',
#  'copyright',
#  'college',
#  'girls',
#  'girls',
#  'ladies',
# ...

# %%
crimeLemma = [wnl.lemmatize(t) for t in stoppedwmtwords]
mtporterlemma = [porter.stem(t) for t in crimeLemma]
mtporterlemma
# Out:
# ['start',
#  'project',
#  'gutenberg',
#  'ebook',
#  'mark',
#  'twain',
#  'speech',
#  'produc',
#  'david',
#  'widger',
#  'mark',
#  'twain',
#  'speech',
#  'mark',
#  'twain',
#  'content',
#  'introduct',
#  'prefac',
#  'stori',
#  'speech',
#  'plymouth',
#  'rock',
#  'pilgrim',
#  'compliment',
#  'degre',
#  'book',
#  'author',
#  'hat',
#  'dedic',
#  'speech',
#  'die',
#  'schrecken',
#  'der',
#  'deutschen',
#  'sprach',
#  'german',
#  'hungarian',
#  'new',
#  'german',
#  'word',
#  'unconsci',
#  'plagiar',
#  'weather',
#  'babi',
#  'child',
#  'great',
#  'discoveri',
#  'educ',
#  'theatr',
#  'goer',
#  'educ',
#  'theatr',
#  'poet',
#  'policeman',
#  'pudd',
#  'nhead',
#  'wilson',
#  'dramat',
#  'dali',
#  'theatr',
#  'dress',
#  'civil',
#  'woman',
#  'dress',
#  'reform',
#  'copyright',
#  'colleg',
#  'girl',
#  'girl',
#  'ladi',
#  'woman',
#  'press',
#  'club',
#  'vote',
#  'woman',
#  'woman',
#  'opinion',
#  'advic',
#  'girl',
# ...

# %%
from nltk import FreqDist
emmadist = FreqDist(mtporterlemma)
emmaitems = emmadist.most_common(50)
for item in emmaitems:
  print (item[0], '\t\t',item[1]/len(MarkTwain))
# Out:
# one 		 0.0007664624173240195
# mr 		 0.0006609859378757599
# year 		 0.0005794174604357726
# time 		 0.00048097274628406366
# said 		 0.0004795663932247535
# know 		 0.0004753473340468231
# day 		 0.00044581391980131046
# man 		 0.0004275313300302788
# go 		 0.000419093211674418
# thing 		 0.00040081062190338635
# get 		 0.00038534073825097497
# like 		 0.0003586200301240825
# good 		 0.00034455649953098124
# well 		 0.0003262739097599496
# new 		 0.0003248675567006395
# never 		 0.0003206484975227091
# see 		 0.00031924214446339894
# great 		 0.00031783579140408884
# clemen 		 0.0003108040261075382
# make 		 0.0003093976730482281
# old 		 0.00030236590775167745
# come 		 0.0002854896710399559
# way 		 0.00028408331798064574
# think 		 0.000275645199624785
# two 		 0.00025876896291306345
# mark 		 0.00025736260985375335
# alway 		 0.0002517371976165128
# life 		 0.0002489244914978926
# made 		 0.0002447054323199622
# take 		 0.00023767366702341156
# u 		 0.00023767366702341156
# ...

# %%
morestopword3=['twain','got','take','made','see','make','get','said','one']
stopwords=stopwords+morestopword3
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', '
# ...

# %%
stoppedwmtwords = [w for w in wmtwords if not w in stopwords]
print(len(stoppedwmtwords))
stoppedwmtwords
# Out:
# 53686
# ['start',
#  'project',
#  'gutenberg',
#  'ebook',
#  'mark',
#  'speeches',
#  'produced',
#  'david',
#  'widger',
#  'mark',
#  'speeches',
#  'mark',
#  'contents',
#  'introduction',
#  'preface',
#  'story',
#  'speech',
#  'plymouth',
#  'rock',
#  'pilgrims',
#  'compliments',
#  'degrees',
#  'books',
#  'authors',
#  'hats',
#  'dedication',
#  'speech',
#  'die',
#  'schrecken',
#  'der',
#  'deutschen',
#  'sprache',
#  'german',
#  'hungarians',
#  'new',
#  'german',
#  'word',
#  'unconscious',
#  'plagiarism',
#  'weather',
#  'babies',
#  'children',
#  'great',
#  'discoveries',
#  'educating',
#  'theatre',
#  'goers',
#  'educational',
#  'theatre',
#  'poets',
#  'policemen',
#  'pudd',
#  'nhead',
#  'wilson',
#  'dramatized',
#  'daly',
#  'theatre',
#  'dress',
#  'civilized',
#  'woman',
#  'dress',
#  'reform',
#  'copyright',
#  'college',
#  'girls',
#  'girls',
#  'ladies',
#  'woman',
#  'press',
#  'club',
#  'votes',
#  'women',
#  'woman',
# ...

# %%
crimeLemma = [wnl.lemmatize(t) for t in stoppedwmtwords]
mtporterlemma = [porter.stem(t) for t in crimeLemma]
mtporterlemma

emmadist = FreqDist(mtporterlemma)
emmaitems = emmadist.most_common(50)
for item in emmaitems:
  print (item[0], '\t\t',item[1]/len(MarkTwain))
# Out:
# mr 		 0.0006609859378757599
# year 		 0.0005794174604357726
# time 		 0.00048097274628406366
# know 		 0.0004753473340468231
# day 		 0.00044581391980131046
# man 		 0.0004275313300302788
# go 		 0.000419093211674418
# thing 		 0.00040081062190338635
# like 		 0.0003586200301240825
# good 		 0.00034455649953098124
# well 		 0.0003262739097599496
# new 		 0.0003248675567006395
# never 		 0.0003206484975227091
# great 		 0.00031783579140408884
# clemen 		 0.0003108040261075382
# old 		 0.00030236590775167745
# come 		 0.0002854896710399559
# way 		 0.00028408331798064574
# think 		 0.000275645199624785
# two 		 0.00025876896291306345
# mark 		 0.00025736260985375335
# alway 		 0.0002517371976165128
# life 		 0.0002489244914978926
# u 		 0.00023767366702341156
# first 		 0.00021798472419306978
# look 		 0.00021095295889651914
# word 		 0.00020673389971858876
# peopl 		 0.00020251484054065836
# may 		 0.00020110848748134823
# long 		 0.00018985766300686722
# ...

# %%
from nltk.collocations import *
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = BigramCollocationFinder.from_words(mtporterlemma)
finder.apply_ngram_filter(lambda w1, w2: len(w1) < 2)
scored = finder.score_ngrams(bigram_measures.raw_freq)
for bscore in scored[:50]:
    print (bscore)
# Out:
# (('mr', 'clemen'), 0.0027753976828223375)
# (('new', 'york'), 0.0022724732704988266)
# (('year', 'ago'), 0.0014715195767984203)
# (('year', 'old'), 0.0007078195432701263)
# (('new', 'england'), 0.0005588049025816787)
# (('fourth', 'juli'), 0.0005215512424095668)
# (('let', 'u'), 0.0005029244123235108)
# (('five', 'year'), 0.000428417091979287)
# (('dear', 'mr'), 0.000409790261893231)
# (('first', 'time'), 0.000409790261893231)
# (('mr', 'roger'), 0.000409790261893231)
# (('seven', 'year'), 0.000409790261893231)
# (('two', 'year'), 0.00039116343180717507)
# (('mr', 'carnegi'), 0.0003725366017211191)
# (('three', 'year'), 0.00035390977163506315)
# (('twichel', 'hartford'), 0.00033528294154900717)
# (('two', 'three'), 0.00033528294154900717)
# (('unit', 'state'), 0.00033528294154900717)
# (('joan', 'arc'), 0.00031665611146295124)
# (('twenti', 'five'), 0.00031665611146295124)
# (('dear', 'joe'), 0.00029802928137689526)
# (('introduc', 'mr'), 0.00029802928137689526)
# ...

# %%
Trigram_measures = nltk.collocations.TrigramAssocMeasures()
finder = TrigramCollocationFinder.from_words(mtporterlemma)
scored = finder.score_ngrams(Trigram_measures.raw_freq)
for bscore in scored[:50]:
    print (bscore)
# Out:
# (('introduc', 'mr', 'clemen'), 0.0002421487911187274)
# (('rev', 'twichel', 'hartford'), 0.0002421487911187274)
# (('twenti', 'five', 'year'), 0.0002421487911187274)
# (('citi', 'new', 'york'), 0.00022352196103267146)
# (('villa', 'di', 'quarto'), 0.00018626830086055954)
# (('five', 'year', 'ago'), 0.00016764147077450358)
# (('first', 'time', 'ever'), 0.00014901464068844763)
# (('forti', 'two', 'year'), 0.0001303878106023917)
# (('mani', 'year', 'ago'), 0.0001303878106023917)
# (('new', 'york', 'citi'), 0.0001303878106023917)
# (('seven', 'year', 'ago'), 0.0001303878106023917)
# (('address', 'dinner', 'given'), 0.00011176098051633573)
# (('di', 'quarto', 'florenc'), 0.00011176098051633573)
# (('honor', 'mr', 'clemen'), 0.00011176098051633573)
# (('mr', 'chang', 'riley'), 0.00011176098051633573)
# (('new', 'england', 'weather'), 0.00011176098051633573)
# (('seven', 'year', 'old'), 0.00011176098051633573)
# (('thirti', 'six', 'year'), 0.00011176098051633573)
# ...

# %%
finder3 = BigramCollocationFinder.from_words(mtporterlemma)
finder3.apply_freq_filter(5)
scored = finder3.score_ngrams(bigram_measures.pmi)
for bscore in scored[:50]:
    print (bscore)
# Out:
# (('mortim', 'durand'), 13.390330202223215)
# (('oliv', 'wendel'), 13.390330202223215)
# (('waldorf', 'astoria'), 13.390330202223215)
# (('gutenberg', 'ebook'), 12.904903375052971)
# (('madam', 'bernhardt'), 12.904903375052971)
# (('warren', 'hast'), 12.904903375052971)
# (('project', 'gutenberg'), 12.682510953716527)
# (('anti', 'doughnut'), 12.542333295668264)
# (('quarri', 'farm'), 12.542333295668264)
# (('helen', 'keller'), 12.12729579638942)
# (('san', 'francisco'), 12.011818578969486)
# (('plymouth', 'rock'), 12.011818578969484)
# (('eng', 'nye'), 11.989792272639484)
# (('fifth', 'ave'), 11.864261390555626)
# (('di', 'quarto'), 11.805367701502057)
# (('joan', 'arc'), 11.542333295668264)
# (('riverdal', 'hudson'), 11.419476547882729)
# (('wendel', 'holm'), 11.319940874331817)
# (('fifth', 'avenu'), 11.25282667847328)
# (('tom', 'sawyer'), 11.188696341053564)
# (('villa', 'di'), 11.182437350581882)
# (('fred', 'grant'), 11.127295796389419)
# (('tom', 'reed'), 11.036693247608513)
# ...

# %%
finder3 = TrigramCollocationFinder.from_words(mtporterlemma)
finder3.apply_freq_filter(5)
scored = finder3.score_ngrams(Trigram_measures.pmi)
for bscore in scored[:50]:
    print (bscore)
# Out:
# (('project', 'gutenberg', 'ebook'), 25.809806750105942)
# (('oliv', 'wendel', 'holm'), 24.71027107655503)
# (('sir', 'mortim', 'durand'), 23.54799964765615)
# (('villa', 'di', 'quarto'), 22.98780505208394)
# (('di', 'quarto', 'florenc'), 22.321228785809136)
# (('rev', 'twichel', 'hartford'), 19.746458236113234)
# (('york', 'villa', 'di'), 18.872327834664002)
# (('mr', 'eng', 'nye'), 18.82553362318506)
# (('address', 'dinner', 'given'), 15.845200656641143)
# (('mr', 'chang', 'riley'), 15.815549534612444)
# (('twenti', 'four', 'hour'), 15.044989307983144)
# (('thirti', 'six', 'year'), 14.76743079611203)
# (('new', 'england', 'weather'), 14.653407605234367)
# (('new', 'york', 'villa'), 14.480010411885242)
# (('citi', 'new', 'york'), 14.277381245370222)
# (('twenti', 'five', 'year'), 14.0033064468121)
# (('new', 'york', 'citi'), 13.499773666706673)
# (('introduc', 'mr', 'clemen'), 12.968683710076142)
# (('seven', 'year', 'ago'), 12.775326588798716)
# ...
